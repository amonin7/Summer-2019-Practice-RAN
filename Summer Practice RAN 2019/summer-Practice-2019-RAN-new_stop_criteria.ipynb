# %% [markdown]
# # Random distribution images

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
roz_rnd_dst_data = []
with open("roz_rnd_dist_NC.txt") as f:
    for line in f:
        roz_rnd_dst_data.append([float(x) for x in line.split()])

roz_rnd_dst_data.sort()
roz_rnd_dst_data = np.array(roz_rnd_dst_data)

incVec = roz_rnd_dst_data[:, 0]
incVec = incVec[::100]
decVec = roz_rnd_dst_data[:, 1]
decVec.sort()
decVec = decVec[::100]
z = roz_rnd_dst_data[:, 2]

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

VMIN = 0
VMAX = 15000
STEP = 1500

def plot_color_map(z, alpha_values, tau_values, alpha_freq= 15, tau_freq=10, dist_type=""):
    z = np.array(z)
    # z = np.log(z)
    Z = z.reshape((len(tau_values), len(alpha_values)))

    plt.figure(figsize=(5, 5))
    ax = plt.gca()

    plt.title("ROZ func 4 vars. with distribution type: " + dist_type)
    plt.xlabel("DECREMENT", fontsize=12)
    plt.ylabel("INCREMENT", fontsize=12)
    plt.xticks([alpha_freq*i for i in range(len(alpha_values[::alpha_freq]))], np.round(alpha_values[::alpha_freq], decimals=3))
    plt.yticks([tau_freq*i for i in range(len(tau_values[::tau_freq]))], [np.round(el, decimals=2) for el in tau_values[::tau_freq]])

    im = ax.imshow(Z, interpolation='bilinear', cmap='winter', aspect='auto', vmin=VMIN, vmax=VMAX)
    # im = ax.imshow(Z, interpolation='bilinear', cmap='winter', aspect='auto')

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.5)

    cbar = plt.colorbar(im, cax=cax)
    cbar.set_ticks(np.arange(VMIN, VMAX, STEP))
    cbar.set_ticklabels(np.arange(VMIN, VMAX, STEP))
    plt.show()

# %%
plot_color_map(z, decVec, incVec, dist_type="random")

# %%
data = []
with open("roz_rnd_dist_NC.txt") as f:
    for line in f:
        data.append([float(x) for x in line.split()])
data = np.array(data)
values = data[1:10000, 3]
x = [i for i in range(1, 10000, 1)]
plt.figure(figsize=(15,5))
plt.plot(x, values)
plt.show()

# %%
roz_uni_dst_data = []
with open("roz_uni_dist_NC.txt") as f:
    for line in f:
        roz_uni_dst_data.append([float(x) for x in line.split()])

roz_uni_dst_data.sort()
roz_uni_dst_data = np.array(roz_uni_dst_data)

incVec_uni = roz_uni_dst_data[:, 0]
incVec_uni = incVec_uni[::100]
decVec_uni = roz_uni_dst_data[:, 1]
decVec_uni.sort()
decVec_uni = decVec_uni[::100]
z_uni = roz_uni_dst_data[:, 2]

# %%
plot_color_map(z_uni, decVec_uni, incVec_uni, dist_type="uniform")

# %%
data = []
with open("roz_uni_dist_NC.txt") as f:
    for line in f:
        data.append([float(x) for x in line.split()])
data = np.array(data)
values = data[1:10000, 3]
x = [i for i in range(1, 10000, 1)]
plt.figure(figsize=(15,5))
plt.plot(x, values)
plt.show()

# %%
plot_color_map(roz4_z_uni, roz4_decVec_uni, roz4_incVec_uni, dist_type="uniform")
plot_color_map(roz4_z, roz4_decVec, roz4_incVec, dist_type="random")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-c68aff4d5948> in <module>
# ----> 1 plot_color_map(roz4_z_uni, roz4_decVec_uni, roz4_incVec_uni, dist_type="uniform")
#       2 plot_color_map(roz4_z, roz4_decVec, roz4_incVec, dist_type="random")
#
# NameError: name 'roz4_z_uni' is not defined

# %%
VMIN = 0
VMAX = 300
STEP = 30

def plot_color_map(z, alpha_values, tau_values, alpha_freq= 15, tau_freq=10, dist_type=""):
    z = np.array(z)
    # z = np.log(z)
    Z = z.reshape((len(tau_values), len(alpha_values)))

    plt.figure(figsize=(5, 5))
    ax = plt.gca()

    plt.title("ROZ func 4 vars. with distribution type: " + dist_type)
    plt.xlabel("DECREMENT", fontsize=12)
    plt.ylabel("INCREMENT", fontsize=12)
    plt.xticks([alpha_freq*i for i in range(len(alpha_values[::alpha_freq]))], np.round(alpha_values[::alpha_freq], decimals=3))
    plt.yticks([tau_freq*i for i in range(len(tau_values[::tau_freq]))], [np.round(el, decimals=2) for el in tau_values[::tau_freq]])

    im = ax.imshow(Z, interpolation='bilinear', cmap='winter', aspect='auto', vmin=VMIN, vmax=VMAX)
    # im = ax.imshow(Z, interpolation='bilinear', cmap='winter', aspect='auto')

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.5)

    cbar = plt.colorbar(im, cax=cax)
    cbar.set_ticks(np.arange(VMIN, VMAX, STEP))
    cbar.set_ticklabels(np.arange(VMIN, VMAX, STEP))
    plt.show()

# %%
roz_uni_dst_data2 = []
with open("roz_uni_dist_NC2.txt") as f:
    for line in f:
        roz_uni_dst_data2.append([float(x) for x in line.split()])

roz_uni_dst_data2.sort()
roz_uni_dst_data2 = np.array(roz_uni_dst_data2)

incVec_uni2 = roz_uni_dst_data2[:, 0]
incVec_uni2 = incVec_uni2[::100]
decVec_uni2 = roz_uni_dst_data2[:, 1]
decVec_uni2.sort()
decVec_uni2 = decVec_uni2[::100]
z_uni2 = roz_uni_dst_data2[:, 2]

# %%
plot_color_map(z_uni2, decVec_uni2, incVec_uni2, dist_type="uniform")

# %%
data = []
with open("roz_uni_dist_NC2.txt") as f:
    for line in f:
        data.append([float(x) for x in line.split()])
data = np.array(data)
values = data[1:10000, 3]
x = [i for i in range(1, 10000, 1)]
plt.figure(figsize=(15,5))
plt.plot(x, values)
plt.show()
